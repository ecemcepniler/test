# %%
import pandas as pd

# %%
load_factor= pd.read_csv('feb24_loadfactor.csv')

# %%
load_factor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   UtilityCompany         5681 non-null   object
#  1   CurrentAccountNumber   5681 non-null   object
#  2   UtilityServiceAddress  5680 non-null   object
#  3   FacilityName           5676 non-null   object
#  4   facilityAddress        5679 non-null   object
#  5   OecFacilityNumber      5681 non-null   int64
#  6   AgencyCodeOEC          5681 non-null   int64
#  7   AgencyName             5681 non-null   object
#  8   ActualOrEstimated      5681 non-null   object
#  9   EnergyUsage            5681 non-null   int64
#  10  DemandUsage            5681 non-null   float64
#  11  NumberOfDays           5681 non-null   int64
#  12  LoadFactor             5681 non-null   float64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 577.1+ KB

# %%
#Accounts having Load Factor higher than 1.
load_factor_higher_1= load_factor.loc[load_factor['LoadFactor'] >= 1]

# %%
load_factor_higher_1
# Out:
#    UtilityCompany   CurrentAccountNumber  \
# 0            NYPA        559390400060000
# 1            NYPA  …....................
# 2            NYPA        600825400000000
# 3            NYPA        400413000010000
# 4            NYPA        061223200020000
# 5            NYPA        889705500050000
# 6            NYPA        235405600020000
# 7            NYPA        116043600050000
# 8            NYPA        950325100000000
# 9            NYPA        674125400060000
# 10           NYPA        372810500070000
# 11           NYPA        146237400090000
# 12           NYPA        549692000020000
# 13           NYPA        101506100030000
# 14           NYPA        948902400080000
# 15           NYPA        309323600080000
# 16           NYPA        036652000060000
# 17           NYPA        661160400080000
# 18           NYPA        304342400050000
# 19           NYPA        442727400000000
# 20           NYPA        150920000070000
# 21           NYPA        935657300040000
# ...

# %%
load_factor_higher_1['AgencyName'].unique()
# Out:
# array(['Department of Parks and Recreation', 'DEP - Bureau of Wastewater',
#        'DEP - Bureau of Water and Sewer Operations', 'Police Department',
#        'New York Public Library ',
#        'DOT Street Lighting & Traffic Control',
#        'Department of Correction', 'DEP - Bureau of Water Supply'],
#       dtype=object)

# %%
load_factor_higher_1.loc[load_factor_feb_higher_1['AgencyName']== 'Police Department']
# Out:
#    UtilityCompany CurrentAccountNumber  \
# 4            NYPA      061223200020000
# 46           NYPA      870567000050000
#
#                        UtilityServiceAddress             FacilityName  \
# 4         1303 DEKALB AVENUE     PARKING LOT         NYPD Parking Lot
# 46  31-22 COLLEGE POINBO ALRMFLUSHINGNY       College Point Tow Pound
#
#                    facilityAddress  OecFacilityNumber  AgencyCodeOEC  \
# 4                  1303 DeKalb Ave             301657          56010
# 46  31-22 College Point Boulevard              401759          56010
#
#            AgencyName ActualOrEstimated  EnergyUsage  DemandUsage  \
# 4   Police Department               EST           89         0.02
# 46  Police Department               ACT           70         0.09
#
#     NumberOfDays  LoadFactor
# 4             32        5.79
# 46            32        1.01

# %%
#To export:
load_factor_higher_1.to_excel('load_factor_higher_1.xlsx')

# %%
#Accounts with Load Factor btw 0.90 and 1.
high_load_factor= load_factor.loc[(load_factor['LoadFactor']> 0.9) & (load_factor['LoadFactor']<1)]

# %%
high_load_factor
# Out:
#     UtilityCompany CurrentAccountNumber  \
# 50            NYPA      561465100050000
# 51     PSEG - LIPA      004030399100000
# 52            NYPA      202702200050000
# 53            NYPA      647494400000000
# 54            NYPA      998816200010000
# ..             ...                  ...
# 169           NYPA      930519100030000
# 170           NYPA      750055500010000
# 171           NYPA      047850100020000
# 172           NYPA      156635000050000
# 173           NYPA      589709400010000
#
#                         UtilityServiceAddress  \
# 50   529 W 35          ST 3GGMANHATTANNY
# 51    Beach 117th St, Rockaway Park, NY 11694
# 52    @ PLYMOUTH ST & HUDSON A BROOKLYN NY 11
# 53    @EAST 79TH STREET & FDR DRV  REG. WIM-7
# 54    UNDERHILL        RO 21SCARSDALENY
# ..                                        ...
# 169                   FIELD HOUSE 82ND STREET
# 170                  9591 SCHLEY AVE *BRONXNY
# 171            ROCHESTER AVE & CARROLL STREET
# ...

# %%
high_load_factor['AgencyName'].unique()
# Out:
# array(['Department of Parks and Recreation', 'DEP - Bureau of Wastewater',
#        'DEP - Bureau of Water Supply', 'Economic Development Corporation',
#        'DEP - Bureau of Water and Sewer Operations', 'Police Department',
#        'Health and Hospitals Corporation', 'Department for the Aging',
#        'Department of Information Technology and Telecommunications',
#        'Department of Education', 'Department of Homeless Services',
#        'DOT Facilities', 'La Guardia Community College',
#        'Department of Correction', 'Brooklyn Public Library',
#        'Department Of Health and Mental Hygiene', 'DOT Bridges',
#        'CUNY Computer Center', 'Bronx Community College',
#        'John Jay College of Criminal Justice', 'Hunter College',
#        'Fire Department', 'Office of Emergency Management',
#        'Snug Harbor Cultural Center', 'City College of New York'],
#       dtype=object)

# %%
#To export:
high_load_factor.to_excel('high_load_factor.xlsx')
